# %%
import seaborn as sns
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os

# size of the image: 48*48 pixels
pic_size = 48

# input path for the images
base_path = "../input/dataset10cat/Datase-Copy/"

plt.figure(0, figsize=(12,20))
cpt = 0

for person in os.listdir(base_path + "train/"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(10,5,cpt)
        img = load_img(base_path + "train/" + person + "/" +os.listdir(base_path + "train/" + person)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %%
for person in os.listdir(base_path + "train"):
    print(str(len(os.listdir(base_path + "train/" + person))) + " " + person + " images")
# Out:
# 107 R images
# 107 I images
# 98 U images
# 98 K images
# 98 S images
# 107 A images
# 107 T images
# 98 V images
# 107 C images
# 107 D images

# %%
from keras.preprocessing.image import ImageDataGenerator
batch_size = 32

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()
datagen_test = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + "train",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "val",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
test_generator = datagen_test.flow_from_directory(base_path + "test",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 1034 images belonging to 10 classes.
# Found 438 images belonging to 10 classes.
# Found 279 images belonging to 10 classes.

# %%
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import pydot

# number of possible label values
nb_classes = 10

# Initialising the CNN
model = Sequential()

# 1 - Convolution
model.add(Conv2D(64,(3,3), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

# 2nd Convolution layer
model.add(Conv2D(128,(5,5), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

# 3rd Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

# 4th Convolution layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))

# Flattening
model.add(Flatten())

# Fully connected layer 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Dropout(0.25))

# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Dropout(0.25))

model.add(Dense(nb_classes, activation='softmax'))
model.summary()


from keras.utils import plot_model 
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model1.png') 
import tensorflow as tf

opt = Adam(lr=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_7 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 4,480,266
# Trainable params: 4,476,298
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
import tensorflow as tf
tf.__version__
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6343119356395735574
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15685569792
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1966044836683844608
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# number of epochs to train the NN
epochs = 50

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 32/32 [==============================] - 144s 4s/step - loss: 1.8620 - accuracy: 0.3726 - val_loss: 4.9948 - val_accuracy: 0.1010
# Epoch 2/50
# 32/32 [==============================] - 106s 3s/step - loss: 0.4096 - accuracy: 0.9399 - val_loss: 2.7535 - val_accuracy: 0.1370
# Epoch 3/50
# 32/32 [==============================] - 117s 4s/step - loss: 0.1721 - accuracy: 0.9881 - val_loss: 1.9313 - val_accuracy: 0.2380
# Epoch 4/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.0871 - accuracy: 0.9991 - val_loss: 1.4869 - val_accuracy: 0.5096
# Epoch 5/50
# 32/32 [==============================] - 112s 3s/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 1.1492 - val_accuracy: 0.5889
# Epoch 6/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.8773 - val_accuracy: 0.7067
# Epoch 7/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.6386 - val_accuracy: 0.8173
# Epoch 8/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.0282 - accuracy: 0.9993 - val_loss: 0.5063 - val_accuracy: 0.8606
# Epoch 9/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.3747 - val_accuracy: 0.8894
# Epoch 10/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2707 - val_accuracy: 0.9231
# Epoch 11/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9375
# Epoch 12/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9375
# Epoch 13/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9327
# Epoch 14/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9303
# Epoch 15/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9495
# Epoch 16/50
# 32/32 [==============================] - 108s 3s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9543
# Epoch 17/50
# 32/32 [==============================] - 107s 3s/step - loss: 0.0076 - accuracy: 0.9997 - val_loss: 0.1698 - val_accuracy: 0.9423
# Epoch 18/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.0101 - accuracy: 0.9999 - val_loss: 0.1602 - val_accuracy: 0.9495
# Epoch 19/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9519
# Epoch 20/50
# 32/32 [==============================] - 114s 4s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9471
# Epoch 21/50
# 32/32 [==============================] - 111s 3s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9447
# Epoch 22/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0151 - accuracy: 0.9993 - val_loss: 0.2161 - val_accuracy: 0.9279
# Epoch 23/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0253 - accuracy: 0.9973 - val_loss: 0.3535 - val_accuracy: 0.8846
# Epoch 24/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0367 - accuracy: 0.9968 - val_loss: 0.8249 - val_accuracy: 0.7428
# Epoch 25/50
# 32/32 [==============================] - 108s 3s/step - loss: 0.0842 - accuracy: 0.9897 - val_loss: 0.5678 - val_accuracy: 0.8101
# Epoch 26/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0360 - accuracy: 0.9979 - val_loss: 0.5094 - val_accuracy: 0.8413
# Epoch 27/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0167 - accuracy: 0.9984 - val_loss: 0.3022 - val_accuracy: 0.9038
# Epoch 28/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9327
# Epoch 29/50
# 32/32 [==============================] - 112s 3s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9495
# Epoch 30/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.0087 - accuracy: 0.9996 - val_loss: 0.2501 - val_accuracy: 0.9159
# Epoch 31/50
# 32/32 [==============================] - 110s 3s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9567
# Epoch 32/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9495
# Epoch 33/50
# 32/32 [==============================] - 115s 4s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9639
# Epoch 34/50
# 32/32 [==============================] - 111s 3s/step - loss: 0.0175 - accuracy: 0.9969 - val_loss: 0.2040 - val_accuracy: 0.9303
# Epoch 35/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0092 - accuracy: 0.9992 - val_loss: 0.1539 - val_accuracy: 0.9543
# Epoch 36/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0134 - accuracy: 0.9969 - val_loss: 0.1934 - val_accuracy: 0.9351
# Epoch 37/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9591
# Epoch 38/50
# 32/32 [==============================] - 111s 4s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9591
# Epoch 39/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9639
# Epoch 40/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9663
# Epoch 41/50
# 32/32 [==============================] - 112s 4s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9567
# Epoch 42/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9591
# Epoch 43/50
# 32/32 [==============================] - 108s 3s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9567
# Epoch 44/50
# 32/32 [==============================] - 109s 3s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9639
# Epoch 45/50
# 32/32 [==============================] - 111s 3s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9615
# Epoch 46/50
# 32/32 [==============================] - 111s 4s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9615
# Epoch 47/50
# 32/32 [==============================] - 115s 4s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9591
# Epoch 48/50
# 32/32 [==============================] - 113s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9615
# Epoch 49/50
# 32/32 [==============================] - 116s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 0.9663
# Epoch 50/50
# 32/32 [==============================] - 117s 4s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9543

# %%
import matplotlib.pyplot as plt

 



plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
predictions = model.predict_generator(generator=test_generator)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = test_generator.classes
class_names = test_generator.class_indices.keys()
from sklearn.metrics import accuracy_score
acnn=accuracy_score(y_test, y_pred)*100
print("TESTING ACCURACY", acnn)
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# TESTING ACCURACY 93.9068100358423
